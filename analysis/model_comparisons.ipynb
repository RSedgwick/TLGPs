# %%
import warnings
warnings.simplefilter("ignore")
from utils.analysis_utils import load_learning_curve_results
import os
import pathlib as pl
from utils.plotting_utils import plot_learning_curve_results
# Out:
# 2023-09-08 17:02:59.788426: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Plot Learning Curves
#
# Notebook for plotting figures from the learning curve data where we plot RMSE and NLPD against number of data points
# for the different test cases

# %%
results_df = load_learning_curve_results()

# %%
potrait_orientation = True
plot_learning_curve_results(results_df, [2], mean=True, save=True, path=pl.Path(os.getcwd())/'plots',
                                file_name=f'learning_curves_seed_{2}_mean', potrait_orientation=potrait_orientation)

# %%
potrait_orientation = True
for seeds in [[1], [2], [3]]:
    plot_learning_curve_results(results_df, seeds,  mean=False, save=True, path=pl.Path(os.getcwd())/'plots',
                                file_name=f'learning_curves_seed_{seeds[0]}', potrait_orientation=potrait_orientation)
    plot_learning_curve_results(results_df, seeds, mean=True, save=True, path=pl.Path(os.getcwd())/'plots',
                                file_name=f'learning_curves_seed_{seeds[0]}_mean', potrait_orientation=potrait_orientation)

# %%
plot_learning_curve_results(results_df, [1,2, 3], mean=True, save=True, path=pl.Path(os.getcwd())/'plots',
                                file_name=f'learning_curves_all_seeds_mean')

# %%
plot_learning_curve_results(results_df,[2],  mean=True)
# plt.savefig(pl.Path(os.getcwd()) / f'plots/metrics_seeds_{2}.svg', bbox_inches='tight')
